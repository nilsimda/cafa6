# %%
from utils.training import ModelConfig, train_model

name = "MLP_C_t5_longer_reduce_lr_on_plateau"

config = ModelConfig(
    name=name,
    learning_rate=0.005,
    epochs=100,
    use_batchnorm=True,
    use_dropout=True,
    batch_size=256,
    use_focal_loss=False,
)

model, best_f_w, history = train_model(config, aspect="C", use_wandb=True, save_path=f"keras_models/{name}.keras")
# Out:
# Loading data for aspect C with taxon_topk=77...
# Data shapes: X_train=(48248, 1152), y_train=(48248, 4041)
# wandb: Currently logged in as: nilsimda to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/data/cafa6/wandb/run-20251205_144355-ka2gk331</code>
# Syncing run <strong><a href='https://wandb.ai/nilsimda/cafa-6/runs/ka2gk331' target="_blank">C_MLP_C_t5_longer_reduce_lr_on_plateau</a></strong> to <a href='https://wandb.ai/nilsimda/cafa-6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nilsimda/cafa-6' target="_blank">https://wandb.ai/nilsimda/cafa-6</a>
# ...

# %%
name = "MLP_F_t5_longer_reduce_lr_on_plateau"

config = ModelConfig(
    name=name,
    learning_rate=0.005,
    epochs=100,
    use_batchnorm=True,
    use_dropout=True,
    batch_size=256,
    use_focal_loss=False,
)

model, best_f_w, history = train_model(config, aspect="F", use_wandb=True, save_path=f"keras_models/{name}.keras")
# Out:
# Loading data for aspect F with taxon_topk=77...
# Data shapes: X_train=(46422, 1152), y_train=(46422, 10131)
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/data/cafa6/wandb/run-20251205_145418-y7g97537</code>
# Syncing run <strong><a href='https://wandb.ai/nilsimda/cafa-6/runs/y7g97537' target="_blank">F_MLP_F_t5_longer_reduce_lr_on_plateau</a></strong> to <a href='https://wandb.ai/nilsimda/cafa-6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nilsimda/cafa-6' target="_blank">https://wandb.ai/nilsimda/cafa-6</a>
#  View run at <a href='https://wandb.ai/nilsimda/cafa-6/runs/y7g97537' target="_blank">https://wandb.ai/nilsimda/cafa-6/runs/y7g97537</a>
# Epoch 1/100
# 174/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2311
# ...

# %%
name = "MLP_P_t5_longer_reduce_lr_on_plateau"

config = ModelConfig(
    name=name,
    learning_rate=0.005,
    epochs=100,
    use_batchnorm=True,
    use_dropout=True,
    batch_size=256,
    use_focal_loss=False,
)

model, best_f_w, history = train_model(config, aspect="P", use_wandb=True, save_path=f"keras_models/{name}.keras")
